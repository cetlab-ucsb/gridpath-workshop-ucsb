# %% [markdown]
# # GridPath Workshop (UCSB)
#
# Initialization

# %%
import os
import sys
import pandas as pd

# Print the current working directory. The result should end with state_model
software_dir = os.getcwd()
os.chdir("..")
print(software_dir)
# Out:
# /Users/Guille/Desktop/state_model/gridpath-workshop-ucsb

# %%
#Setting this as the primary directory for all future use
# This is be the main folder where all files are created and stored in. 
directory = os.getcwd()
print(directory)
# Out:
# /Users/Guille/Desktop/state_model

# %%
# Defining the database directory - where the database file will be created and stored. 
db_dir = f"{directory}/db"

# Defining CSV inputs directory - where the state level input files are stored. 
csv_dir = f"{directory}/gridpath_input_csvs"

#Defining scenario folder location
scen_dir = f"{directory}/scenarios"

# %% [markdown]
# # GridPath: Capacity Expansion
# The following section is for running a capacity expansion model in GridPath.

# %% [markdown]
# ## User edit section
# Add the folder name with input csvs and provide a name for this database.

# %%
# Speciific  model for this run.
# Add the name of the specific mode folder file by replacing the worth between " " 
gridpath_input_csvs = "7_2050_12-capex"

# Add your database name below between "" or leave blank to use input_csvs_gridpath as database name
db_name = ""
db_name = db_name if db_name else gridpath_input_csvs
print(f"Database name is set to: {db_name}")
# Out:
# Database name is set to: 7_2050_12-capex

# %% [markdown]
# ### Creating database, importing state inputs and importing scenarios to the database for modeling

# %%
# !python {directory}/gridpath/db/create_database.py --database {db_dir}/{db_name}.db

# %%
# !python {directory}/gridpath/db/utilities/port_csvs_to_db.py --database {db_dir}/{db_name}.db --csv_location {csv_dir}/{gridpath_input_csvs}
# Out:
# Importing data for subscenario solver_options_id, table options_solver from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/solver...
# ...importing CSV 4_gurobi_4th_high_mipgap.csv
#    ...importing data from 4_gurobi_4th_high_mipgap.csv
# ...importing CSV 1_glpk.csv
#    ...importing data from 1_glpk.csv
# ...importing CSV 5_ipopt.csv
#    ...importing data from 5_ipopt.csv
# ...importing CSV 3_cplex_high_mipgap.csv
#    ...importing data from 3_cplex_high_mipgap.csv
# ...importing CSV 6_highs.csv
#    ...importing data from 6_highs.csv
# ...importing CSV 2_cbc.csv
#    ...importing data from 2_cbc.csv
# Importing data for subscenario temporal_scenario_id, table temporal from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal...
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/1_7periods_2020-2050
#    ...importing data from nan
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/2_5periods_2020-2040
#    ...importing data from nan
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/3_3periods_2020-2030
#    ...importing data from nan
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/4_4periods_2020-2035
#    ...importing data from nan
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/5_4periods_2020-2050
#    ...importing data from nan
# Importing data for subscenario temporal_scenario_id, table temporal_periods from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal...
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/1_7periods_2020-2050
#    ...importing data from period_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/2_5periods_2020-2040
#    ...importing data from period_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/3_3periods_2020-2030
#    ...importing data from period_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/4_4periods_2020-2035
#    ...importing data from period_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/5_4periods_2020-2050
#    ...importing data from period_params.csv
# Importing data for subscenario temporal_scenario_id, table temporal_superperiods from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal...
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/1_7periods_2020-2050
#    ...importing data from superperiods.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/2_5periods_2020-2040
#    ...importing data from superperiods.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/3_3periods_2020-2030
#    ...importing data from superperiods.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/4_4periods_2020-2035
#    ...importing data from superperiods.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/5_4periods_2020-2050
#    ...importing data from superperiods.csv
# Importing data for subscenario temporal_scenario_id, table temporal_horizons from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal...
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/1_7periods_2020-2050
#    ...importing data from horizon_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/2_5periods_2020-2040
#    ...importing data from horizon_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/3_3periods_2020-2030
#    ...importing data from horizon_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/4_4periods_2020-2035
#    ...importing data from horizon_params.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/5_4periods_2020-2050
#    ...importing data from horizon_params.csv
# Importing data for subscenario temporal_scenario_id, table temporal from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal...
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/1_7periods_2020-2050
#    ...importing data from structure.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/2_5periods_2020-2040
#    ...importing data from structure.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/3_3periods_2020-2030
#    ...importing data from structure.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/4_4periods_2020-2035
#    ...importing data from structure.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/5_4periods_2020-2050
#    ...importing data from structure.csv
# Importing data for subscenario temporal_scenario_id, table temporal_horizon_timepoints_start_end from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal...
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/1_7periods_2020-2050
#    ...importing data from horizon_timepoints.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/2_5periods_2020-2040
#    ...importing data from horizon_timepoints.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/3_3periods_2020-2030
#    ...importing data from horizon_timepoints.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/4_4periods_2020-2035
#    ...importing data from horizon_timepoints.csv
# ...importing data from directory /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/temporal/5_4periods_2020-2050
#    ...importing data from horizon_timepoints.csv
# Importing data for subscenario project_portfolio_scenario_id, table project_portfolios from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_portfolios...
# ...importing CSV 8_project_portfolios_B_NuclearPVboth.csv
#    ...importing data from 8_project_portfolios_B_NuclearPVboth.csv
# ...importing CSV 7_project_portfolios_BPHS_PVboth.csv
#    ...importing data from 7_project_portfolios_BPHS_PVboth.csv
# ...importing CSV 1_project_portfolios_base.csv
#    ...importing data from 1_project_portfolios_base.csv
# ...importing CSV 4_project_portfolios_NoStorNew.csv
#    ...importing data from 4_project_portfolios_NoStorNew.csv
# ...importing CSV 10_project_portfolios_BPHS_NoNewCoalPVboth.csv
#    ...importing data from 10_project_portfolios_BPHS_NoNewCoalPVboth.csv
# ...importing CSV 5_project_portfolios_NoStorNew_NoCoalPipeline.csv
#    ...importing data from 5_project_portfolios_NoStorNew_NoCoalPipeline.csv
# ...importing CSV 2_project_portfolios_base_NoCoalPipeline.csv
#    ...importing data from 2_project_portfolios_base_NoCoalPipeline.csv
# ...importing CSV 6_project_portfolios_B_PVboth.csv
#    ...importing data from 6_project_portfolios_B_PVboth.csv
# ...importing CSV 9_project_portfolios_BPHS_NuclearPVboth.csv
#    ...importing data from 9_project_portfolios_BPHS_NuclearPVboth.csv
# ...importing CSV 3_project_portfolios_base_NoGasNew.csv
#    ...importing data from 3_project_portfolios_base_NoGasNew.csv
# Importing data for subscenario load_scenario_id, table system_load from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/system_load/system_load...
# ...importing CSV 1_base.csv
#    ...importing data from 1_base.csv
# Importing data for subscenario load_zone_scenario_id, table geography_load_zones from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/system_load/load_zones...
# ...importing CSV 2_statesAsZones_MidOverGenPenalty.csv
#    ...importing data from 2_statesAsZones_MidOverGenPenalty.csv
# ...importing CSV 3_statesAsZones_SoftOverGenPenalty.csv
#    ...importing data from 3_statesAsZones_SoftOverGenPenalty.csv
# ...importing CSV 4_statesAsZones_HardOverGenPenalty.csv
#    ...importing data from 4_statesAsZones_HardOverGenPenalty.csv
# ...importing CSV 1_statesAsZones_NoOverGenPenalty.csv
#    ...importing data from 1_statesAsZones_NoOverGenPenalty.csv
# Importing data for subscenario project_load_zone_scenario_id, table project_load_zones from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_load_zones...
# ...importing CSV 1_project_load_zones_base.csv
#    ...importing data from 1_project_load_zones_base.csv
# Importing data for subscenario project_specified_capacity_scenario_id, table project_specified_capacity from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_specified_capacity...
# ...importing CSV 4_project_specified_capacity_4550.csv
#    ...importing data from 4_project_specified_capacity_4550.csv
# ...importing CSV 13_project_specified_capacity_7075_no2020ret.csv
#    ...importing data from 13_project_specified_capacity_7075_no2020ret.csv
# ...importing CSV 10_project_specified_capacity_3540_no2020ret.csv
#    ...importing data from 10_project_specified_capacity_3540_no2020ret.csv
# ...importing CSV 1_project_specified_capacity_base.csv
#    ...importing data from 1_project_specified_capacity_base.csv
# ...importing CSV 3_project_specified_capacity_3540.csv
#    ...importing data from 3_project_specified_capacity_3540.csv
# ...importing CSV 9_project_specified_capacity_3035_no2020ret.csv
#    ...importing data from 9_project_specified_capacity_3035_no2020ret.csv
# ...importing CSV 5_project_specified_capacity_5055.csv
#    ...importing data from 5_project_specified_capacity_5055.csv
# ...importing CSV 6_project_specified_capacity_7075.csv
#    ...importing data from 6_project_specified_capacity_7075.csv
# ...importing CSV 2_project_specified_capacity_3035.csv
#    ...importing data from 2_project_specified_capacity_3035.csv
# ...importing CSV 12_project_specified_capacity_5055_no2020ret.csv
#    ...importing data from 12_project_specified_capacity_5055_no2020ret.csv
# ...importing CSV 7_project_specified_capacity_noret.csv
#    ...importing data from 7_project_specified_capacity_noret.csv
# ...importing CSV 8_project_specified_capacity_base_no2020ret.csv
#    ...importing data from 8_project_specified_capacity_base_no2020ret.csv
# ...importing CSV 11_project_specified_capacity_4550_no2020ret.csv
#    ...importing data from 11_project_specified_capacity_4550_no2020ret.csv
# Importing data for subscenario project_specified_fixed_cost_scenario_id, table project_specified_fixed_cost from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_specified_fixed_cost...
# ...importing CSV 3_project_specified_fixed_cost_zero.csv
#    ...importing data from 3_project_specified_fixed_cost_zero.csv
# ...importing CSV 2_project_specified_fixed_cost_cea.csv
#    ...importing data from 2_project_specified_fixed_cost_cea.csv
# ...importing CSV 1_project_specified_fixed_cost_merit.csv
#    ...importing data from 1_project_specified_fixed_cost_merit.csv
# Importing data for subscenario project_new_cost_scenario_id, table project_new_cost from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_new_cost...
# ...importing CSV 18_VREhigh_SThigh_CONVhigh.csv
#    ...importing data from 18_VREhigh_SThigh_CONVhigh.csv
# ...importing CSV 6_VREhigh_STlow_CONVmid.csv
#    ...importing data from 6_VREhigh_STlow_CONVmid.csv
# ...importing CSV 20_PVmid_WDhigh_STmid_CONVmid.csv
#    ...importing data from 20_PVmid_WDhigh_STmid_CONVmid.csv
# ...importing CSV 17_VRElow_SThigh_CONVhigh.csv
#    ...importing data from 17_VRElow_SThigh_CONVhigh.csv
# ...importing CSV 11_VRElow_STmid_CONVhigh.csv
#    ...importing data from 11_VRElow_STmid_CONVhigh.csv
# ...importing CSV 12_VREhigh_STmid_CONVhigh.csv
#    ...importing data from 12_VREhigh_STmid_CONVhigh.csv
# ...importing CSV 16_VREmid_SThigh_CONVhigh.csv
#    ...importing data from 16_VREmid_SThigh_CONVhigh.csv
# ...importing CSV 9_VREhigh_SThigh_CONVmid.csv
#    ...importing data from 9_VREhigh_SThigh_CONVmid.csv
# ...importing CSV 13_VREmid_STlow_CONVhigh.csv
#    ...importing data from 13_VREmid_STlow_CONVhigh.csv
# ...importing CSV 7_VREmid_SThigh_CONVmid.csv
#    ...importing data from 7_VREmid_SThigh_CONVmid.csv
# ...importing CSV 10_VREmid_STmid_CONVhigh.csv
#    ...importing data from 10_VREmid_STmid_CONVhigh.csv
# ...importing CSV 4_VREmid_STlow_CONVmid.csv
#    ...importing data from 4_VREmid_STlow_CONVmid.csv
# ...importing CSV 8_VRElow_SThigh_CONVmid.csv
#    ...importing data from 8_VRElow_SThigh_CONVmid.csv
# ...importing CSV 14_VRElow_STlow_CONVhigh.csv
#    ...importing data from 14_VRElow_STlow_CONVhigh.csv
# ...importing CSV 19_PVhigh_WDmid_STmid_CONVmid.csv
#    ...importing data from 19_PVhigh_WDmid_STmid_CONVmid.csv
# ...importing CSV 5_VRElow_STlow_CONVmid.csv
#    ...importing data from 5_VRElow_STlow_CONVmid.csv
# ...importing CSV 3_VREhigh_STmid_CONVmid.csv
#    ...importing data from 3_VREhigh_STmid_CONVmid.csv
# ...importing CSV 15_VREhigh_STlow_CONVhigh.csv
#    ...importing data from 15_VREhigh_STlow_CONVhigh.csv
# ...importing CSV 1_VREmid_STmid_CONVmid.csv
#    ...importing data from 1_VREmid_STmid_CONVmid.csv
# ...importing CSV 2_VRElow_STmid_CONVmid.csv
#    ...importing data from 2_VRElow_STmid_CONVmid.csv
# Importing data for subscenario project_new_potential_scenario_id, table project_new_potential from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_new_potential...
# ...importing CSV 2_project_new_potential_base_PVboth.csv
#    ...importing data from 2_project_new_potential_base_PVboth.csv
# ...importing CSV 1_project_new_potential_base.csv
#    ...importing data from 1_project_new_potential_base.csv
# Importing data for subscenario project_capacity_group_requirement_scenario_id, table project_capacity_group_requirements from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_capacity_groups/requirements...
# Importing data for subscenario project_capacity_group_scenario_id, table project_capacity_groups from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_capacity_groups/projects...
# Importing data for subscenario project_fuel_scenario_id, table project_fuels from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_fuels...
# ...importing CSV Supercritical_Coal_MP_new-1-base.csv
#    ...importing data from Supercritical_Coal_MP_new-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_1985_1989_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Large_1985_1989_CG-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-1-base.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-1-base.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_JH-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_JH-1-base.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_WB-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_CG-1-base.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-1-base.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-1-base.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-1-base.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-1-base.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-1-base.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-1-base.csv
# ...importing CSV CCGT_GJ-1-base.csv
#    ...importing data from CCGT_GJ-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_CG-1-base.csv
# ...importing CSV Biomass_MP-1-base.csv
#    ...importing data from Biomass_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-1-base.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-1-base.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-1-base.csv
# Importing data for subscenario heat_rate_curves_scenario_id, table project_heat_rate_curves from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_heat_rate_curves...
# ...importing CSV Supercritical_Coal_MP_new-1-base.csv
#    ...importing data from Supercritical_Coal_MP_new-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_1985_1989_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Large_1985_1989_CG-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-1-base.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-1-base.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_JH-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_JH-1-base.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_WB-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_CG-1-base.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-1-base.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-1-base.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-1-base.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-1-base.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-1-base.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-1-base.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-1-base.csv
# ...importing CSV CCGT_GJ-1-base.csv
#    ...importing data from CCGT_GJ-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_CG-1-base.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_CG-1-base.csv
# ...importing CSV Biomass_MP-1-base.csv
#    ...importing data from Biomass_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-1-base.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-1-base.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-1-base.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-1-base.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-1-base.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-1-base.csv
# Importing data for subscenario variable_om_curves_scenario_id, table project_variable_om_curves from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_variable_om_curves...
# Importing data for subscenario startup_chars_scenario_id, table project_startup_chars from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_startup_chars...
# Importing data for subscenario hydro_operational_chars_scenario_id, table project_hydro_operational_chars from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_hydro_operational_chars...
# ...importing CSV Hydro_Storage_MP-1-project_hydro_opchars_12days.csv
#    ...importing data from Hydro_Storage_MP-1-project_hydro_opchars_12days.csv
# Importing data for subscenario variable_generator_profile_scenario_id, table project_variable_generator_profiles from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_variable_generator_profiles...
# ...importing CSV wind_MP_J-1-12days.csv
#    ...importing data from wind_MP_J-1-12days.csv
# ...importing CSV solarPV_tilt_MP_AD-1-12days.csv
#    ...importing data from solarPV_tilt_MP_AD-1-12days.csv
# ...importing CSV solarPV_roof_MP_new-1-12days.csv
#    ...importing data from solarPV_roof_MP_new-1-12days.csv
# ...importing CSV solarPV_tilt_MP_AE-1-12days.csv
#    ...importing data from solarPV_tilt_MP_AE-1-12days.csv
# ...importing CSV Hydro_ROR_MP_pipeline-1-12days.csv
#    ...importing data from Hydro_ROR_MP_pipeline-1-12days.csv
# ...importing CSV solarPV_single_MP_new-1-12days.csv
#    ...importing data from solarPV_single_MP_new-1-12days.csv
# ...importing CSV wind_MP_C-1-12days.csv
#    ...importing data from wind_MP_C-1-12days.csv
# ...importing CSV wind_MP_D-1-12days.csv
#    ...importing data from wind_MP_D-1-12days.csv
# ...importing CSV wind_MP_new-1-12days.csv
#    ...importing data from wind_MP_new-1-12days.csv
# ...importing CSV solarPV_tilt_MP_K-1-12days.csv
#    ...importing data from solarPV_tilt_MP_K-1-12days.csv
# ...importing CSV wind_MP_Q-1-12days.csv
#    ...importing data from wind_MP_Q-1-12days.csv
# ...importing CSV Hydro_ROR_MP-1-12days.csv
#    ...importing data from Hydro_ROR_MP-1-12days.csv
# ...importing CSV solarPV_tilt_MP_T-1-12days.csv
#    ...importing data from solarPV_tilt_MP_T-1-12days.csv
# ...importing CSV solarPV_tilt_MP_new-1-12days.csv
#    ...importing data from solarPV_tilt_MP_new-1-12days.csv
# ...importing CSV wind_MP_P-1-12days.csv
#    ...importing data from wind_MP_P-1-12days.csv
# ...importing CSV solarPV_tilt_MP_U-1-12days.csv
#    ...importing data from solarPV_tilt_MP_U-1-12days.csv
# Importing data for subscenario project_operational_chars_scenario_id, table project_operational_chars from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_operational_chars...
# ...importing CSV 1_project_operational_chars_hydro_day.csv
#    ...importing data from 1_project_operational_chars_hydro_day.csv
# ...importing CSV 4_project_operational_chars_hydro_day_UniformAll.csv
#    ...importing data from 4_project_operational_chars_hydro_day_UniformAll.csv
# ...importing CSV 2_project_operational_chars_hydro_month.csv
#    ...importing data from 2_project_operational_chars_hydro_month.csv
# ...importing CSV 3_project_operational_chars_hydro_day_UniformCoal.csv
#    ...importing data from 3_project_operational_chars_hydro_day_UniformCoal.csv
# Importing data for subscenario project_availability_scenario_id, table project_availability from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_availability/project_availability_types...
# ...importing CSV 1_project_availability_types_derating85.csv
#    ...importing data from 1_project_availability_types_derating85.csv
# ...importing CSV 4_project_availability_types_deratingCFCEA.csv
#    ...importing data from 4_project_availability_types_deratingCFCEA.csv
# ...importing CSV 2_project_availability_types_derating50.csv
#    ...importing data from 2_project_availability_types_derating50.csv
# ...importing CSV 3_project_availability_types_deratingCEA.csv
#    ...importing data from 3_project_availability_types_deratingCEA.csv
# Importing data for subscenario endogenous_availability_scenario_id, table project_availability_endogenous from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_availability/project_availability_endogenous...
# Importing data for subscenario exogenous_availability_scenario_id, table project_availability_exogenous from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/project/project_availability/project_availability_exogenous...
# ...importing CSV Supercritical_Coal_2015_2019_CG-1-derating85.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-2-derating50.csv
# ...importing CSV CCGT_GJ-3-deratingCEA.csv
#    ...importing data from CCGT_GJ-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-2-derating50.csv
# ...importing CSV Supercritical_Coal_MP_new-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_MP_new-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-4-deratingCFCEA.csv
# ...importing CSV CCGT_GJ-1-derating85.csv
#    ...importing data from CCGT_GJ-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_CG-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_CG-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-1-derating85.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-1-derating85.csv
# ...importing CSV Biomass_MP-1-derating85.csv
#    ...importing data from Biomass_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-2-derating50.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-2-derating50.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-3-deratingCEA.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-3-deratingCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-2-derating50.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-1-derating85.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-2-derating50.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-1-derating85.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-1-derating85.csv
# ...importing CSV Biomass_MP-3-derating2020.csv
#    ...importing data from Biomass_MP-3-derating2020.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-3-deratingCEA.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-2-derating50.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-2-derating50.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-2-derating50.csv
# ...importing CSV Hydro_ROR_MP-4-deratingCFCEA.csv
#    ...importing data from Hydro_ROR_MP-4-deratingCFCEA.csv
# ...importing CSV CCGT_GJ-2-derating50.csv
#    ...importing data from CCGT_GJ-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-2-derating50.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-3-deratingCEA.csv
# ...importing CSV Nuclear_MH-4-deratingCFCEA.csv
#    ...importing data from Nuclear_MH-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-3-deratingCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-2-derating50.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-1-derating85.csv
# ...importing CSV Nuclear_MH-3-deratingCEA.csv
#    ...importing data from Nuclear_MH-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-1-derating85.csv
# ...importing CSV Hydro_Pumped_MP_new-3-deratingCEA.csv
#    ...importing data from Hydro_Pumped_MP_new-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-2-derating50.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-2-derating50.csv
# ...importing CSV Battery_MP_new-4-deratingCFCEA.csv
#    ...importing data from Battery_MP_new-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-4-deratingCFCEA.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-4-deratingCFCEA.csv
# ...importing CSV Battery_MP_new-3-deratingCEA.csv
#    ...importing data from Battery_MP_new-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-1-derating85.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-1-derating85.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-1-derating85.csv
# ...importing CSV Biomass_MP-2-derating50.csv
#    ...importing data from Biomass_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-1-derating85.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-1-derating85.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-3-deratingCEA.csv
# ...importing CSV Hydrogen_MP_new-4-deratingCFCEA.csv
#    ...importing data from Hydrogen_MP_new-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_JH-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_JH-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-2-derating50.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-1-derating85.csv
# ...importing CSV Hydro_Storage_MP-4-deratingCFCEA.csv
#    ...importing data from Hydro_Storage_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-2-derating50.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-1-derating85.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-1-derating85.csv
# ...importing CSV Hydro_Storage_MP-3-deratingCEA.csv
#    ...importing data from Hydro_Storage_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-4-deratingCFCEA.csv
# ...importing CSV Supercritical_Coal_MP_new-1-derating85.csv
#    ...importing data from Supercritical_Coal_MP_new-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_1985_1989_CG-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_1985_1989_CG-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_CG-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_CG-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_WB-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_WB-3-deratingCEA.csv
# ...importing CSV Hydro_Pumped_MP_new-4-deratingCFCEA.csv
#    ...importing data from Hydro_Pumped_MP_new-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_WB-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_WB-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_CG-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_CG-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_1985_1989_CG-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_1985_1989_CG-1-derating85.csv
# ...importing CSV CCGT_GJ-4-deratingCFCEA.csv
#    ...importing data from CCGT_GJ-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_JH-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_JH-2-derating50.csv
# ...importing CSV Nuclear_MH-2-derating50.csv
#    ...importing data from Nuclear_MH-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_CG-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_CG-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_CG-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_CG-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_CG-2-derating50.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_CG-2-derating50.csv
# ...importing CSV Supercritical_Coal_MP_new-3-deratingCEA.csv
#    ...importing data from Supercritical_Coal_MP_new-3-deratingCEA.csv
# ...importing CSV Supercritical_Coal_MP_new-2-derating50.csv
#    ...importing data from Supercritical_Coal_MP_new-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-2-derating50.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-2-derating50.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-1-derating85.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-1-derating85.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-4-deratingCFCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-4-deratingCFCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-3-deratingCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-3-deratingCEA.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-1-derating85.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-1-derating85.csv
# ...
# ...importing CSV Subcritical_Coal_Large_2005_2009_CG-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_CG-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-1-afCEA.csv
# ...importing CSV Hydro_ROR_MP-1-afCEA.csv
#    ...importing data from Hydro_ROR_MP-1-afCEA.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-1-afCEA.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-1-afCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-1-afCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_WB-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_WB-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-1-afCEA.csv
# ...importing CSV Nuclear_MH-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Nuclear_MH-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Supercritical_Coal_MP_new-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_MP_new-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-1-afCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-1-afCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-1-afCEA.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Battery_MP_new-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Battery_MP_new-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Hydro_ROR_MP_pipeline-1-afCEA.csv
#    ...importing data from Hydro_ROR_MP_pipeline-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Hydrogen_MP_new-2-afCEA_noVRE.csv
#    ...importing data from Hydrogen_MP_new-2-afCEA_noVRE.csv
# ...importing CSV Hydro_Storage_MP-1-afCEA.csv
#    ...importing data from Hydro_Storage_MP-1-afCEA.csv
# ...importing CSV Supercritical_Coal_2020_2024_MP-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2020_2024_MP-2-afCEA_noVRE.csv
# ...importing CSV Hydrogen_MP_new-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Hydrogen_MP_new-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-1-afCEA.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_2015_2019_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2015_2019_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-2-afCEA_noVRE.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_JH-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_JH-2-afCEA_noVRE.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-2-afCEA_noVRE.csv
# ...importing CSV Supercritical_Coal_2010_2014_MP-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2010_2014_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_BR-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_BR-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-2-afCEA_noVRE.csv
# ...importing CSV Biomass_MP-1-afCEA.csv
#    ...importing data from Biomass_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1980_1984_CG-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1980_1984_CG-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2000_2004_WB-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2000_2004_WB-2-afCEA_noVRE.csv
# ...importing CSV Supercritical_Coal_2015_2019_CG-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Supercritical_Coal_2015_2019_CG-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-2-afCEA_noVRE.csv
# ...importing CSV CCGT_GJ-2-afCEA_noVRE.csv
#    ...importing data from CCGT_GJ-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2015_2019_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_2015_2019_MP-1-afCEA.csv
# ...importing CSV Supercritical_Coal_MP_new-1-afCEA.csv
#    ...importing data from Supercritical_Coal_MP_new-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_CG-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_CG-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_WB-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_WB-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-1-afCEA.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MH-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MH-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_JH-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_JH-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Battery_MP_new-1-afCEA.csv
#    ...importing data from Battery_MP_new-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV CCGT_GJ-3-afCEA_noVRE_noHydro.csv
#    ...importing data from CCGT_GJ-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-2-afCEA_noVRE.csv
# ...importing CSV Hydro_Pumped_MP_new-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Hydro_Pumped_MP_new-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Small_1990_1994_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1990_1994_MP-2-afCEA_noVRE.csv
# ...importing CSV Supercritical_Coal_2010_2014_CG-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2010_2014_CG-2-afCEA_noVRE.csv
# ...importing CSV CCGT_GJ-1-afCEA.csv
#    ...importing data from CCGT_GJ-1-afCEA.csv
# ...importing CSV Hydrogen_MP_new-1-afCEA.csv
#    ...importing data from Hydrogen_MP_new-1-afCEA.csv
# ...importing CSV Nuclear_MH-2-afCEA_noVRE.csv
#    ...importing data from Nuclear_MH-2-afCEA_noVRE.csv
# ...importing CSV Supercritical_Coal_2015_2019_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Supercritical_Coal_2015_2019_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_1985_1989_CG-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_1985_1989_CG-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Supercritical_Coal_2015_2019_MH-2-afCEA_noVRE.csv
#    ...importing data from Supercritical_Coal_2015_2019_MH-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2005_2009_WB-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_2005_2009_WB-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1975_1979_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Small_1975_1979_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Large_2010_2014_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Large_2010_2014_MP-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_2010_2014_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Small_2010_2014_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Large_2000_2004_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_2000_2004_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Supercritical_Coal_2025_2029_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Supercritical_Coal_2025_2029_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_1995_1999_MP-1-afCEA.csv
#    ...importing data from Subcritical_Coal_Large_1995_1999_MP-1-afCEA.csv
# ...importing CSV Subcritical_Coal_Small_1995_1999_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_1995_1999_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_2005_2009_MP-2-afCEA_noVRE.csv
#    ...importing data from Subcritical_Coal_Large_2005_2009_MP-2-afCEA_noVRE.csv
# ...importing CSV Hydro_Pumped_MP_new-1-afCEA.csv
#    ...importing data from Hydro_Pumped_MP_new-1-afCEA.csv
# ...importing CSV Battery_MP_new-2-afCEA_noVRE.csv
#    ...importing data from Battery_MP_new-2-afCEA_noVRE.csv
# ...importing CSV Subcritical_Coal_Small_1985_1989_MP-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Small_1985_1989_MP-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Subcritical_Coal_Large_1985_1989_CG-3-afCEA_noVRE_noHydro.csv
#    ...importing data from Subcritical_Coal_Large_1985_1989_CG-3-afCEA_noVRE_noHydro.csv
# ...importing CSV Hydro_Pumped_MP_new-2-afCEA_noVRE.csv
#    ...importing data from Hydro_Pumped_MP_new-2-afCEA_noVRE.csv
# Importing data for subscenario project_elcc_chars_scenario_id, table project_elcc_chars from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/reliability/prm/project_elcc_chars...
# ...importing CSV 2_project_elcc_chars_afCEA_noVRE.csv
#    ...importing data from 2_project_elcc_chars_afCEA_noVRE.csv
# ...importing CSV 1_project_elcc_chars_afCEA.csv
#    ...importing data from 1_project_elcc_chars_afCEA.csv
# ...importing CSV 3_project_elcc_chars_afCEA_noVRE_noHydro.csv
#    ...importing data from 3_project_elcc_chars_afCEA_noVRE_noHydro.csv
# Importing data for subscenario prm_requirement_scenario_id, table system_prm_requirement from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/reliability/prm/system_prm_requirement...
# ...importing CSV 4_system_prm_requirement_prm120.csv
#    ...importing data from 4_system_prm_requirement_prm120.csv
# ...importing CSV 2_system_prm_requirement_prm110.csv
#    ...importing data from 2_system_prm_requirement_prm110.csv
# ...importing CSV 1_system_prm_requirement_prm100.csv
#    ...importing data from 1_system_prm_requirement_prm100.csv
# ...importing CSV 3_system_prm_requirement_prm115.csv
#    ...importing data from 3_system_prm_requirement_prm115.csv
# Importing data for subscenario local_capacity_zone_scenario_id, table geography_local_capacity_zones from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/reliability/local_capacity/geography_local_capacity_zones...
# Importing data for subscenario project_local_capacity_zone_scenario_id, table project_local_capacity_zones from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/reliability/local_capacity/project_local_capacity_zones...
# Importing data for subscenario project_local_capacity_chars_scenario_id, table project_local_capacity_chars from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/reliability/local_capacity/project_local_capacity_chars...
# Importing data for subscenario local_capacity_requirement_scenario_id, table system_local_capacity_requirement from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/reliability/local_capacity/system_local_capacity_requirement...
# Importing data for subscenario market_scenario_id, table geography_markets from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/markets/geography_markets...
# Importing data for subscenario load_zone_market_scenario_id, table load_zone_markets from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/markets/load_zone_markets...
# Importing data for subscenario market_price_scenario_id, table market_prices from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/markets/prices...
# Importing data for subscenario market_volume_scenario_id, table market_volume from /Users/Guille/Desktop/state_model/gridpath_input_csvs/7_2050_12-capex/markets/volume...

# %%
# !python {directory}/gridpath/db/utilities/scenario.py --database {db_dir}/{db_name}.db --csv_path {csv_dir}/{gridpath_input_csvs}/scenarios.csv
# Out:
# Loading scenarios...
# ...VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# ...VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# ...VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# ...VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-4_2035_12-capex-MP
# ...VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-4_2035_12-capex-MP
# ...VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-4_2035_12-capex-MP

# %%
# This will print out all possible scenarios available
scenario_csv = pd.read_csv(f"{csv_dir}/{gridpath_input_csvs}/scenarios.csv")
column_names = scenario_csv.columns[1:]

# Print scenario names
print("Available scenarios:")
for name in column_names:
    print(name)
# Out:
# Available scenarios:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-4_2035_12-capex-MP
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-4_2035_12-capex-MP
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-4_2035_12-capex-MP

# %% [markdown]
# ## Select scenarios from the list above and add to the `selected_scenario` below before running.

# %% [markdown]
# ### User Edit Section

# %%
# Add or remove scenarios from above to the list below:
scen_list = ["VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP",
             "VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP", 
             "VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP"]

# %% [markdown]
# ### Running selected scenarios

# %%
# for selected_scenario in scen_list:
#     !python {directory}/gridpath/gridpath/run_end_to_end.py --database {db_dir}/{db_name}.db --scenario {selected_scenario} --solver cbc --solver_executable {directory}\solver\CBC\bin\cbc.exe --scenario_location {scen_dir}

# For Mac user, run below:
for selected_scenario in scen_list:
   # !python {directory}/gridpath/gridpath/run_end_to_end.py --database {db_dir}/{db_name}.db --scenario {selected_scenario} --scenario_location {scen_dir}
# Out:
# Running scenario VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP end to end
# Process ID is 1837
# End-to-end run started on 2025-02-13 19:37:47.998182
# Getting inputs... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
#
# Running optimization for scenario VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# Building model...
# Loading data...
# Creating problem instance...
# Solving...
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Sep  3 2024
#
# command line - /Users/Guille/opt/anaconda3/envs/wri/bin/cbc -prep sos -printingOptions all -import /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmphazzovg1.pyomo.lp -stat=1 -solve -solu /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmphazzovg1.pyomo.soln (default strategy 1)
# Multiple matches for prep - possible completions:
# PrepN(ames)
# preprocess
# Multiple matches for sos - possible completions:
# sosO(ptions)
# sosP(rioritize)
# Option for printingOptions changed from normal to all
#  CoinLpIO::readLp(): Maximization problem reformulated as minimization
# Coin0009I Switching back to maximization to get correct duals etc
# Presolve 238806 (-433461) rows, 153237 (-230407) columns and 1238018 (-879763) elements
# Statistics for presolved model
#
#
# Problem has 238806 rows, 153237 columns (31985 with objective) and 1238018 elements
# There are 4320 singletons with objective
# Column breakdown:
# 120973 of type 0.0->inf, 29671 of type 0.0->up, 864 of type lo->inf,
# 865 of type lo->up, 864 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 0 of type 0.0->1.0
# Row breakdown:
# 576 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 1764 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 1 of type G other, 207656 of type L 0.0, 0 of type L 1.0,
# 27945 of type L other, 0 of type Range 0.0->1.0, 864 of type Range other,
# 0 of type Free
# Presolve 238806 (-433461) rows, 153237 (-230407) columns and 1238018 (-879763) elements
# Perturbing problem by 0.001% of 4.9280228e+08 - largest nonzero change 492.80227 ( 8.0264399%) - largest zero change 492.7978
# 0  Obj 2.2083834e+10 Primal inf 4.9561021e+09 (5221)
# 1000  Obj -4.7700984e+10 Primal inf 9.2798821e+08 (4930)
# 2000  Obj -6.1730867e+10 Primal inf 16706850 (3760)
# 3000  Obj -6.6478343e+10 Primal inf 21936425 (9848)
# 4000  Obj -7.1869917e+10 Primal inf 19311809 (13457)
# 5000  Obj -7.5427184e+10 Primal inf 15840672 (14458)
# 6000  Obj -7.7863184e+10 Primal inf 15527295 (15678)
# 7000  Obj -7.93469e+10 Primal inf 14634306 (16477)
# 8000  Obj -8.0414411e+10 Primal inf 12061575 (17187)
# 9000  Obj -8.1091437e+10 Primal inf 11670720 (17250)
# 10000  Obj -8.1236265e+10 Primal inf 9772999.7 (15728)
# 11000  Obj -8.1397167e+10 Primal inf 10448718 (16236)
# 12000  Obj -8.1573004e+10 Primal inf 7037096.7 (14199)
# 13000  Obj -8.1733387e+10 Primal inf 6627870.5 (14588)
# 14000  Obj -8.1874773e+10 Primal inf 5962575.1 (13970)
# 15000  Obj -8.1926372e+10 Primal inf 7695511.2 (12300)
# 16000  Obj -8.1957218e+10 Primal inf 4463218 (11431)
# 17000  Obj -8.1994115e+10 Primal inf 7668070 (10967)
# 18000  Obj -8.2015801e+10 Primal inf 7186514.7 (9776)
# 19000  Obj -8.2032981e+10 Primal inf 2886723 (8150)
# 20000  Obj -8.2051372e+10 Primal inf 11337244 (9687)
# 21000  Obj -8.2067673e+10 Primal inf 3949370.1 (9173)
# 22000  Obj -8.2082872e+10 Primal inf 2364572 (7869)
# 23000  Obj -8.2106427e+10 Primal inf 2037844 (9778)
# 24000  Obj -8.2123226e+10 Primal inf 2002713.7 (9453)
# 25000  Obj -8.2145338e+10 Primal inf 2364113.1 (8032)
# 26000  Obj -8.2155314e+10 Primal inf 2086780.5 (7871)
# 27000  Obj -8.2165759e+10 Primal inf 2102463.7 (8109)
# 28000  Obj -8.2175295e+10 Primal inf 1258204.6 (7101)
# 29000  Obj -8.2184266e+10 Primal inf 5516690.1 (9641)
# 30000  Obj -8.2191956e+10 Primal inf 1672247.7 (8375)
# 31000  Obj -8.2201056e+10 Primal inf 1401801.6 (6404)
# 32000  Obj -8.2208563e+10 Primal inf 1688184 (7850)
# 33000  Obj -8.2215807e+10 Primal inf 2105148.9 (7902)
# 34000  Obj -8.2222285e+10 Primal inf 1378845.9 (6409)
# 35000  Obj -8.2230746e+10 Primal inf 1146899 (6392)
# 36000  Obj -8.2235845e+10 Primal inf 1118406.6 (6532)
# 37000  Obj -8.2240991e+10 Primal inf 885209.81 (6198)
# 38000  Obj -8.2246881e+10 Primal inf 949492.58 (5929)
# 39000  Obj -8.2251895e+10 Primal inf 743804.91 (5966)
# 40000  Obj -8.2256763e+10 Primal inf 1306027.8 (6409)
# 41000  Obj -8.2262559e+10 Primal inf 903301.86 (6129)
# 42000  Obj -8.2267526e+10 Primal inf 1005768.2 (5915)
# 43000  Obj -8.2272946e+10 Primal inf 1125120.3 (7895)
# 44000  Obj -8.2276601e+10 Primal inf 3833762.3 (6364)
# 44939  Obj -8.2280171e+10 Primal inf 5969505.1 (8486)
# 45939  Obj -8.2289602e+10 Primal inf 6985718.2 (6622)
# 46939  Obj -8.2296397e+10 Primal inf 426565.5 (4839)
# 47939  Obj -8.2302495e+10 Primal inf 226107.9 (4039)
# 48939  Obj -8.2306623e+10 Primal inf 252463.86 (4254)
# 49939  Obj -8.2309896e+10 Primal inf 208888.75 (3902)
# 50939  Obj -8.2313914e+10 Primal inf 156572.3 (3730)
# 51939  Obj -8.2315633e+10 Primal inf 142487.01 (3665)
# 52939  Obj -8.2316659e+10 Primal inf 67945.851 (3180)
# 53939  Obj -8.2317165e+10 Primal inf 25419.669 (2706)
# 54939  Obj -8.23175e+10 Primal inf 16179.771 (2537)
# 55939  Obj -8.2317618e+10 Primal inf 122.37059 (1967)
# 56561  Obj -8.2317631e+10
# 56561  Obj -8.125117e+10 Dual inf 4741673.4 (3846)
# 57561  Obj -8.1250256e+10 Dual inf 3764323.8 (4378)
# 58561  Obj -8.124945e+10 Dual inf 1308571.4 (3140)
# 59561  Obj -8.1248856e+10 Dual inf 780551.79 (2492)
# 60561  Obj -8.1248585e+10 Dual inf 276720.01 (1573)
# 61561  Obj -8.1248369e+10 Dual inf 69968.784 (845)
# 62542  Obj -8.1248286e+10
# Optimal - objective value -8.1248286e+10
# After Postsolve, objective -8.1248286e+10, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -8.124828649e+10 - 62542 iterations time 12.782, Presolve 0.52
# Total time (CPU seconds):       16.58   (Wallclock seconds):       17.12
#
# Saving results...
# ...solver termination condition: optimal.
# ...exporting CSV results
# Summarizing results...
# Importing results... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
# system_load_zone_timepoint
# system_prm
# project_period
# project_timepoint
# project_fuel_burn
# project_elcc_simple
# transmission_period
# transmission_timepoint
# system_spinning_reserves
# results system cost
# Processing results... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
# aggregate capacity costs by load zone
# aggregate variable curtailment
# aggregate dispatch by technology
# aggregate dispatch by technology-period
# aggregate costs
# aggregate emissions by technology-period
# aggregate tx capacity costs by load zone
# aggregate tx capacity costs by load zone
# aggregate transmission imports exports
# Done. Run finished on 2025-02-13 19:38:54.953431.
# Running scenario VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP end to end
# Process ID is 1901
# End-to-end run started on 2025-02-13 19:38:59.483056
# Getting inputs... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
#
# Running optimization for scenario VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# Building model...
# Loading data...
# Creating problem instance...
# Solving...
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Sep  3 2024
#
# command line - /Users/Guille/opt/anaconda3/envs/wri/bin/cbc -prep sos -printingOptions all -import /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmp4sjjunor.pyomo.lp -stat=1 -solve -solu /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmp4sjjunor.pyomo.soln (default strategy 1)
# Multiple matches for prep - possible completions:
# PrepN(ames)
# preprocess
# Multiple matches for sos - possible completions:
# sosO(ptions)
# sosP(rioritize)
# Option for printingOptions changed from normal to all
#  CoinLpIO::readLp(): Maximization problem reformulated as minimization
# Coin0009I Switching back to maximization to get correct duals etc
# Presolve 238806 (-433461) rows, 153237 (-230407) columns and 1238018 (-879763) elements
# Statistics for presolved model
#
#
# Problem has 238806 rows, 153237 columns (31985 with objective) and 1238018 elements
# There are 4320 singletons with objective
# Column breakdown:
# 120973 of type 0.0->inf, 29671 of type 0.0->up, 864 of type lo->inf,
# 865 of type lo->up, 864 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 0 of type 0.0->1.0
# Row breakdown:
# 576 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 1764 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 1 of type G other, 207656 of type L 0.0, 0 of type L 1.0,
# 27945 of type L other, 0 of type Range 0.0->1.0, 864 of type Range other,
# 0 of type Free
# Presolve 238806 (-433461) rows, 153237 (-230407) columns and 1238018 (-879763) elements
# Perturbing problem by 0.001% of 4.9280228e+08 - largest nonzero change 492.80227 ( 8.0264399%) - largest zero change 492.7978
# 0  Obj 2.204855e+10 Primal inf 4.9561021e+09 (5221)
# 1000  Obj -4.7736268e+10 Primal inf 9.2798821e+08 (4930)
# 2000  Obj -6.1766151e+10 Primal inf 16706850 (3760)
# 3000  Obj -6.6395997e+10 Primal inf 17493108 (8421)
# 4000  Obj -7.1467116e+10 Primal inf 16693673 (12763)
# 5000  Obj -7.5024718e+10 Primal inf 14766334 (14154)
# 6000  Obj -7.7606798e+10 Primal inf 15124415 (15096)
# 7000  Obj -7.9498307e+10 Primal inf 35758896 (17794)
# 8000  Obj -8.0636934e+10 Primal inf 14135494 (16460)
# 9000  Obj -8.1177652e+10 Primal inf 11062648 (16797)
# 10000  Obj -8.1344184e+10 Primal inf 14108806 (16848)
# 11000  Obj -8.1476752e+10 Primal inf 7617457 (14155)
# 12000  Obj -8.1640937e+10 Primal inf 6536553.5 (13434)
# 13000  Obj -8.1778675e+10 Primal inf 6265924.3 (12820)
# 14000  Obj -8.1920013e+10 Primal inf 5290846.6 (12374)
# 15000  Obj -8.1981182e+10 Primal inf 6846131.9 (11647)
# 16000  Obj -8.2012691e+10 Primal inf 4639138.3 (11052)
# 17000  Obj -8.2043423e+10 Primal inf 3804740.6 (10031)
# 18000  Obj -8.2066366e+10 Primal inf 3092336.3 (8855)
# 19000  Obj -8.2079503e+10 Primal inf 7474904.5 (9603)
# 20000  Obj -8.2094315e+10 Primal inf 2535113.8 (7575)
# 21000  Obj -8.2109878e+10 Primal inf 2417962.1 (7567)
# 22000  Obj -8.2122007e+10 Primal inf 2189948.9 (7779)
# 23000  Obj -8.2148395e+10 Primal inf 2283250.7 (7861)
# 24000  Obj -8.2173066e+10 Primal inf 1891833.1 (7612)
# 25000  Obj -8.2185222e+10 Primal inf 1597299.2 (7376)
# 26000  Obj -8.2198345e+10 Primal inf 1598255.9 (7208)
# 27000  Obj -8.2207198e+10 Primal inf 1880155.1 (7054)
# 28000  Obj -8.2217019e+10 Primal inf 2069926.8 (7166)
# 29000  Obj -8.2224038e+10 Primal inf 1647586.5 (6825)
# 30000  Obj -8.2231837e+10 Primal inf 1580241 (6446)
# 31000  Obj -8.2239968e+10 Primal inf 1562367.6 (6623)
# 32000  Obj -8.2248927e+10 Primal inf 1470683.2 (8103)
# 33000  Obj -8.22577e+10 Primal inf 1214714.2 (6417)
# 34000  Obj -8.2263885e+10 Primal inf 1132885.1 (6011)
# 35000  Obj -8.2272898e+10 Primal inf 1219693.2 (6169)
# 36000  Obj -8.2278634e+10 Primal inf 1091681.7 (5919)
# 37000  Obj -8.228393e+10 Primal inf 935681.2 (6027)
# 38000  Obj -8.2290111e+10 Primal inf 745895.38 (5677)
# 39000  Obj -8.2295237e+10 Primal inf 1059502.6 (5799)
# 40000  Obj -8.2301205e+10 Primal inf 2549353 (8066)
# 41000  Obj -8.2306306e+10 Primal inf 732173.31 (5742)
# 42000  Obj -8.2310277e+10 Primal inf 658639.74 (5419)
# 43000  Obj -8.2316593e+10 Primal inf 750469.77 (5425)
# 44000  Obj -8.2322182e+10 Primal inf 571348.45 (5177)
# 45000  Obj -8.2328682e+10 Primal inf 472998.48 (5481)
# 46000  Obj -8.2335355e+10 Primal inf 458943.64 (4740)
# 47000  Obj -8.2340925e+10 Primal inf 405428.88 (4497)
# 48000  Obj -8.2344375e+10 Primal inf 237510.66 (3691)
# 49000  Obj -8.2350204e+10 Primal inf 471531.83 (3567)
# 50000  Obj -8.2352111e+10 Primal inf 117047.53 (3011)
# 51000  Obj -8.2353375e+10 Primal inf 62623.491 (2726)
# 52000  Obj -8.2354142e+10 Primal inf 26924.657 (2340)
# 53000  Obj -8.2354488e+10 Primal inf 14115.98 (2078)
# 54000  Obj -8.2354664e+10 Primal inf 928.66167 (1675)
# 54856  Obj -8.2354684e+10
# 54856  Obj -8.128674e+10 Dual inf 2502239.8 (3757)
# 55856  Obj -8.1285993e+10 Dual inf 786841.95 (2816)
# 56856  Obj -8.1285721e+10 Dual inf 259683.87 (1936)
# 57856  Obj -8.12854e+10 Dual inf 125732.4 (1320)
# 58856  Obj -8.1285228e+10 Dual inf 53776.655 (610)
# 59453  Obj -8.1285168e+10
# Optimal - objective value -8.1285168e+10
# After Postsolve, objective -8.1285168e+10, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -8.128516824e+10 - 59453 iterations time 7.732, Presolve 0.52
# Total time (CPU seconds):       11.55   (Wallclock seconds):       11.95
#
# Saving results...
# ...solver termination condition: optimal.
# ...exporting CSV results
# Summarizing results...
# Importing results... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
# system_load_zone_timepoint
# system_prm
# project_period
# project_timepoint
# project_fuel_burn
# project_elcc_simple
# transmission_period
# transmission_timepoint
# system_spinning_reserves
# results system cost
# Processing results... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
# aggregate capacity costs by load zone
# aggregate variable curtailment
# aggregate dispatch by technology
# aggregate dispatch by technology-period
# aggregate costs
# aggregate emissions by technology-period
# aggregate tx capacity costs by load zone
# aggregate tx capacity costs by load zone
# aggregate transmission imports exports
# Done. Run finished on 2025-02-13 19:40:02.253734.
# Running scenario VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP end to end
# Process ID is 1952
# End-to-end run started on 2025-02-13 19:40:06.497492
# Getting inputs... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
#
# Running optimization for scenario VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# Building model...
# Loading data...
# Creating problem instance...
# Solving...
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Sep  3 2024
#
# command line - /Users/Guille/opt/anaconda3/envs/wri/bin/cbc -prep sos -printingOptions all -import /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmpq04ydizr.pyomo.lp -stat=1 -solve -solu /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmpq04ydizr.pyomo.soln (default strategy 1)
# Multiple matches for prep - possible completions:
# PrepN(ames)
# preprocess
# Multiple matches for sos - possible completions:
# sosO(ptions)
# sosP(rioritize)
# Option for printingOptions changed from normal to all
#  CoinLpIO::readLp(): Maximization problem reformulated as minimization
# Coin0009I Switching back to maximization to get correct duals etc
# Presolve 238806 (-433461) rows, 153237 (-230407) columns and 1238018 (-879763) elements
# Statistics for presolved model
#
#
# Problem has 238806 rows, 153237 columns (31985 with objective) and 1238018 elements
# There are 4320 singletons with objective
# Column breakdown:
# 120973 of type 0.0->inf, 29671 of type 0.0->up, 864 of type lo->inf,
# 865 of type lo->up, 864 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 0 of type 0.0->1.0
# Row breakdown:
# 576 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 1764 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 1 of type G other, 207656 of type L 0.0, 0 of type L 1.0,
# 27945 of type L other, 0 of type Range 0.0->1.0, 864 of type Range other,
# 0 of type Free
# Presolve 238806 (-433461) rows, 153237 (-230407) columns and 1238018 (-879763) elements
# Perturbing problem by 0.001% of 4.9280228e+08 - largest nonzero change 492.80227 ( 8.0264399%) - largest zero change 492.7978
# 0  Obj 2.1900561e+10 Primal inf 4.9561021e+09 (5221)
# 1000  Obj -4.7884257e+10 Primal inf 9.2798821e+08 (4930)
# 2000  Obj -6.191414e+10 Primal inf 16706850 (3760)
# 3000  Obj -6.6543986e+10 Primal inf 17493108 (8421)
# 4000  Obj -7.1615105e+10 Primal inf 16693673 (12763)
# 5000  Obj -7.5172707e+10 Primal inf 14766334 (14154)
# 6000  Obj -7.7754787e+10 Primal inf 15124415 (15096)
# 7000  Obj -7.9646296e+10 Primal inf 35758896 (17794)
# 8000  Obj -8.0784923e+10 Primal inf 14135494 (16460)
# 9000  Obj -8.1325641e+10 Primal inf 11062648 (16797)
# 10000  Obj -8.1492173e+10 Primal inf 14108806 (16848)
# 11000  Obj -8.1624741e+10 Primal inf 7617457 (14155)
# 12000  Obj -8.1788926e+10 Primal inf 6536553.5 (13434)
# 13000  Obj -8.1926664e+10 Primal inf 6265924.3 (12820)
# 14000  Obj -8.2068002e+10 Primal inf 5290846.6 (12374)
# 15000  Obj -8.2129171e+10 Primal inf 6846131.9 (11647)
# 16000  Obj -8.216068e+10 Primal inf 4639138.3 (11052)
# 17000  Obj -8.2191412e+10 Primal inf 3804740.6 (10031)
# 18000  Obj -8.2214355e+10 Primal inf 3092336.3 (8855)
# 19000  Obj -8.2227492e+10 Primal inf 7474904.5 (9603)
# 20000  Obj -8.2242305e+10 Primal inf 2535113.8 (7575)
# 21000  Obj -8.2257867e+10 Primal inf 2417962.1 (7567)
# 22000  Obj -8.2269996e+10 Primal inf 2189948.9 (7779)
# 23000  Obj -8.2296384e+10 Primal inf 2283250.7 (7861)
# 24000  Obj -8.2321055e+10 Primal inf 1891833.1 (7612)
# 25000  Obj -8.2333211e+10 Primal inf 1597299.2 (7376)
# 26000  Obj -8.2346334e+10 Primal inf 1598255.9 (7208)
# 27000  Obj -8.2355187e+10 Primal inf 1880155.1 (7054)
# 28000  Obj -8.2365008e+10 Primal inf 2069926.8 (7166)
# 29000  Obj -8.2372027e+10 Primal inf 1647586.5 (6825)
# 30000  Obj -8.2379826e+10 Primal inf 1580241 (6446)
# 31000  Obj -8.2387957e+10 Primal inf 1562367.6 (6623)
# 32000  Obj -8.2396916e+10 Primal inf 1470683.2 (8103)
# 33000  Obj -8.2405689e+10 Primal inf 1214714.2 (6417)
# 34000  Obj -8.2411874e+10 Primal inf 1132885.1 (6011)
# 35000  Obj -8.2420887e+10 Primal inf 1219693.2 (6169)
# 36000  Obj -8.2426623e+10 Primal inf 1091681.7 (5919)
# 37000  Obj -8.2431919e+10 Primal inf 935681.2 (6027)
# 38000  Obj -8.24381e+10 Primal inf 745895.38 (5677)
# 39000  Obj -8.2443226e+10 Primal inf 1059502.6 (5799)
# 40000  Obj -8.2449194e+10 Primal inf 2549353 (8066)
# 41000  Obj -8.2454295e+10 Primal inf 732173.31 (5742)
# 42000  Obj -8.2458266e+10 Primal inf 658639.74 (5419)
# 43000  Obj -8.2464582e+10 Primal inf 750469.77 (5425)
# 44000  Obj -8.2470171e+10 Primal inf 571348.45 (5177)
# 45000  Obj -8.2476671e+10 Primal inf 472998.48 (5481)
# 46000  Obj -8.2483344e+10 Primal inf 458943.64 (4740)
# 47000  Obj -8.2488914e+10 Primal inf 405428.88 (4497)
# 48000  Obj -8.2492364e+10 Primal inf 237510.66 (3691)
# 49000  Obj -8.2502553e+10 Primal inf 471531.83 (3567)
# 50000  Obj -8.2504461e+10 Primal inf 117047.53 (3011)
# 51000  Obj -8.2505725e+10 Primal inf 62623.491 (2726)
# 52000  Obj -8.2506491e+10 Primal inf 26924.657 (2340)
# 53000  Obj -8.2506838e+10 Primal inf 14115.98 (2078)
# 54000  Obj -8.2507014e+10 Primal inf 928.66167 (1675)
# 54856  Obj -8.2507034e+10
# 54856  Obj -8.143909e+10 Dual inf 2502239.8 (3757)
# 55856  Obj -8.1438343e+10 Dual inf 786841.95 (2816)
# 56856  Obj -8.143807e+10 Dual inf 259683.87 (1936)
# 57856  Obj -8.143775e+10 Dual inf 125732.4 (1320)
# 58856  Obj -8.1437578e+10 Dual inf 53776.655 (610)
# 59453  Obj -8.1437518e+10
# Optimal - objective value -8.1437518e+10
# After Postsolve, objective -8.1437518e+10, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -8.143751758e+10 - 59453 iterations time 7.522, Presolve 0.50
# Total time (CPU seconds):       11.20   (Wallclock seconds):       11.57
#
# Saving results...
# ...solver termination condition: optimal.
# ...exporting CSV results
# Summarizing results...
# Importing results... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
# system_load_zone_timepoint
# system_prm
# project_period
# project_timepoint
# project_fuel_burn
# project_elcc_simple
# transmission_period
# transmission_timepoint
# system_spinning_reserves
# results system cost
# Processing results... (connected to database /Users/Guille/Desktop/state_model/db/7_2050_12-capex.db)
# aggregate capacity costs by load zone
# aggregate variable curtailment
# aggregate dispatch by technology
# aggregate dispatch by technology-period
# aggregate costs
# aggregate emissions by technology-period
# aggregate tx capacity costs by load zone
# aggregate tx capacity costs by load zone
# aggregate transmission imports exports
# Done. Run finished on 2025-02-13 19:41:06.956299.

# %% [markdown]
# # Visualization: Capacity Expansion
# The following section is for visualizing the results from the GridPath Capacity Expansion model above.

# %%
# Checking the directory is correct - should be state_model folder
os.chdir(software_dir)
print(os.getcwd())
# Out:
# /Users/Guille/Desktop/state_model/gridpath-workshop-ucsb

# %%
# loading packages and setting results folder
from loading_utils import * 
from plotting_utils import * 
from processing_utils import *
from pdf_report import * 

path_to_scenarios = f"{directory}/scenarios"
print(path_to_scenarios)
# Out:
# /Users/Guille/Desktop/state_model/scenarios

# %% [markdown]
# Loading necessary functions for the zones, scenarios labels `<scenario_labels.csv>` and technology colors `<technology_labels.csv>` to plot the graph for new and existing capacity

# %%
scen_labels_     = pd.read_csv(directory + '/gridpath_input_csvs/scenario_labels-capex.csv') 
tech_labels_     = pd.read_csv(directory + '/gridpath_input_csvs/technology_labels-capex.csv') 
dispatch_labels_ = pd.read_csv(directory + '/gridpath_input_csvs/dispatch_labels-capex.csv')

# %% [markdown]
# Load new and existing capacity across different scenarios, grouping the capacity by technology.

# %%
capacity_         = _load_capacity(scen_labels_, path_to_scenarios, gp_model = 'capex')
grouped_capacity_ = _group_capacity_technologies(capacity_, tech_labels_)
grouped_capacity_
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
#                                               Scenario  Period   Technology  \
# 0    VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...    2020      Battery
# 1    VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...    2020      Battery
# 2    VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...    2020         Coal
# 3    VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...    2020         Coal
# 4    VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...    2020  Curtailment
# ..                                                 ...     ...          ...
# 283  VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_...    2030        Solar
# 284  VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_...    2030    Tx_Losses
# 285  VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_...    2030    Tx_Losses
# 286  VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_...    2030         Wind
# 287  VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_...    2030         Wind
#
#                Zone    Status      Power  Energy
# 0    Madhya_Pradesh       new      0.000     0.0
# 1    Madhya_Pradesh  existing      0.000     0.0
# 2    Madhya_Pradesh       new      0.000     0.0
# 3    Madhya_Pradesh  existing  38777.703     0.0
# 4    Madhya_Pradesh       new      0.000     0.0
# ..              ...       ...        ...     ...
# 283  Madhya_Pradesh  existing   2255.000     0.0
# 284  Madhya_Pradesh       new      0.000     0.0
# 285  Madhya_Pradesh  existing      0.000     0.0
# 286  Madhya_Pradesh       new      0.000     0.0
# 287  Madhya_Pradesh  existing   2515.000     0.0
#
# [288 rows x 7 columns]

# %% [markdown]
# Plotting the new and existing capacity. Add title name for the plot.

# %%
_plot_new_and_existing_capacity(grouped_capacity_, scen_labels_, tech_labels_,
                                units        = 1e3,
                                units_label  = 'Existing & New Capacity (GW)',
                                legend       = True,
                                save         = True,
                                y_grid_inc   = 25,
                                title        = '',
                                file_name    = directory + r'/plots/group_installed_capacity-capex-MP.png')

# %% [markdown]
# Energy dispatch by scenarios, zone and date

# %%
dispatch_         = _load_energy_dispatch(scen_labels_, path_to_scenarios, gp_model = 'capex')
grouped_dispatch_ = _group_dispatch_technologies(dispatch_, tech_labels_)
grouped_dispatch_
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
#                                               Scenario Period   Technology  \
# 0    VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_...   2020         Coal
# 1    VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_...   2020          Gas
# 2    VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_...   2020       Diesel
# 3    VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_...   2020        Hydro
# 4    VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_...   2020        Other
# ..                                                 ...    ...          ...
# 139  VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...   2030       Export
# 140  VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...   2030  Curtailment
# 141  VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...   2030    Tx_Losses
# 142  VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...   2030       Import
# 143  VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Re...   2030     Shedding
#
#                Zone        Energy
# 0    Madhya_Pradesh  3.973108e+07
# 1    Madhya_Pradesh  0.000000e+00
# 2    Madhya_Pradesh  0.000000e+00
# 3    Madhya_Pradesh  3.651732e+06
# 4    Madhya_Pradesh  8.897508e+04
# ..              ...           ...
# 139  Madhya_Pradesh  0.000000e+00
# 140  Madhya_Pradesh  0.000000e+00
# 141  Madhya_Pradesh -2.913762e+06
# 142  Madhya_Pradesh  4.162516e+07
# 143  Madhya_Pradesh  0.000000e+00
#
# [144 rows x 5 columns]

# %% [markdown]
# Load energy dispatch

# %%
# Enter a title of your choice between the quotation marks ('') under title = ''.
_plot_dispatch(grouped_dispatch_, scen_labels_, tech_labels_, 
               units        = 1e6, 
               units_label  = r'Electricity Generation (TWh)',
               save         = True,
               legend       = True,
               y_grid_inc   = 50,
               title        = '',
               file_name    = directory + r'/plots/group_electricity_generation-capex-MP.png')

# %%
ed_ = _processing_energy_dispatch(scen_labels_, path_to_scenarios, model = 'capex')
ed_ = _group_dispatch_technologies_by_zone_and_date_production(ed_, tech_labels_)
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP

# %% [markdown]
# Plotting energy dispatch

# %%
# Plot energy dispatch for a given day
_plot_zone_energy_dispatch_production(ed_, scen_labels_, tech_labels_, dispatch_labels_,
                                      save      = True,
                                      legend    = True,
                                      file_name = directory + r'/plots/energy_dispatch-capex-MP.png')

# %% [markdown]
# Load Greenhouse Gas (GHG) emissions and load energy demand for different scenarios

# %%
emissions_, demand_ = _load_GHG_emissions(scen_labels_, path_to_scenarios, gp_model = 'capex')
emissions_

# %% [markdown]
# Plot GHG emissions for different scenarios

# %%
# Enter a title of your choice between the quotation marks ('') under title = ''.
_plot_emissions(emissions_, scen_labels_, 
                units      = 1e6,
                unit_label = r'GHG Emissions (MtCO$_2$)',
                save       = True,
                legend     = True,
                title      = '',
                file_name  = directory + r'/plots/GHG_emissions-capex-MP.png')

# %% [markdown]
# Processing GHG emissions intensity for different scenarios

# %%
intesity_, demand_ = _GHG_emissions_intensity(emissions_, demand_)
intesity_

# %% [markdown]
# Plot system Levelized Cost of Electricity (LCOE) for different scenarios

# %%
# Enter a title of your choice between the quotation marks ('') under title = ''.
_plot_emissions_intensity(intesity_, scen_labels_, 
                          unit_label = r'GHG Intensity (MtCO$_2$/MWh)',
                          save       = True,
                          legend     = True,
                          title      = '',
                          file_name  = directory + r'/plots/GHG_emissions_intensity-capex-MP.png')

# %% [markdown]
# Load system cost data for different scenarios

# %%
system_cost_ = _load_system_cost(scen_labels_, path_to_scenarios, gp_model = 'capex')
system_cost_

# %% [markdown]
# Plot system Levelized Cost of Electricity (LCOE) for different scenarios

# %%
# Enter a title of your choice between the quotation marks ('') under title = ''.
_plot_system_cost(system_cost_, scen_labels_, 
                  unit_label = r'Costs (USD per MWh)', 
                  save       = True, 
                  legend     = True,
                  title      = '', 
                  file_name  = directory + r'/plots/system_cost-capex-MP.png')

# %%
# Replace with a specific scenario if needed, otherwise leave blank
scenario = 'VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110-3_2030_12-capex-MP' 
# Replace with 'new' or existing' so only new capacity is shown, otherwise leave blank for new and existing
status = 'new' 
filtered_capacity_ = _filter_capacity(grouped_capacity_, scenario, status)
filtered_capacity_

# %% [markdown]
# ## PDF Report Output

# %%
# Option to add tables at the end of the PDF
add_tables = False  # Set to True to add tables; False to exclude tables

# %%
# Define file paths based on the existing directory variable
plot_details_csv = directory + r'/gridpath_input_csvs/plot_details-capex.csv'
output_pdf_filename = directory + r'/Gridpath_Capacity_Expansion_Report.pdf' 

tables = [grouped_dispatch_, grouped_capacity_, emissions_, intesity_, system_cost_]  # List of DataFrames

# Generate the PDF
generate_pdf_report(directory, plot_details_csv, output_pdf_filename, tables=tables, add_tables=add_tables)
