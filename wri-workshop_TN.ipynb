# %% [markdown]
# ## Run GridPath v0.14.1
#
# Navigate (`cd`) to the directory where you want to install *GridPath*, for instance (in Mac):

# %%
cd /Users/Guille/Desktop/state-level_model
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# /Users/Guille/Desktop/state-level_model

# %% [markdown]
# Make (`mkdir`) a directory (`~/csvs/`) to save the csvs files and another folder (`~/db/`) to save the database. Copy the input `input_csvs` to the csvs folder.

# %%
mkdir csvs
# Out:
# mkdir: csvs: File exists

# %%
mkdir db
# Out:
# mkdir: db: File exists

# %% [markdown]
# ### Create a database
#
# You need to know the path to *GridPath* files `path_to_gridpath` and give the path `path_to_database` where you want to create the database. Give a name to the database `<database_name.db>`. The database has a .db extension. Example `~/db/`

# %%
# %run -i /Users/Guille/Desktop/state-level_model/gridpath/db/create_database.py \
        --database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db
# Out:
# WARNING: The database file /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db already exists. Please
#                 delete it before re-creating the database

# %% [markdown]
# ### Import filets to a database
#
# Import the `.csv` with the path (`--csv_path`) to the `~/csvs/folder_name/` to the database (`--database`) withe name `<database_name.db>` with the following command,

# %%
# %run -i /Users/Guille/Desktop/state-level_model/gridpath/db/utilities/port_csvs_to_db.py \
        --database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db \
        --csv_location /Users/Guille/Desktop/state-level_model/csvs/TN_7-2050-24

# %% [markdown]
# ### Import scenarios to database
#
# Import the scenarios on `<scenarios.csv>` to the (`--database`) file with the path (`--csv_path`) to the folder with the scearios `~/csvs/folder_name/` with the following command,

# %%
# %run -i /Users/Guille/Desktop/state-level_model/gridpath/db/utilities/scenario.py \
        --database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db \
        --csv_path /Users/Guille/Desktop/state-level_model/csvs/TN_7-2050-24/scenarios.csv
# Out:
# Loading scenarios...
# ...VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# ...VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# ...VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# ...VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_4_2035_24
# ...VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_4_2035_24
# ...VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_4_2035_24

# %% [markdown]
# ### Solve a scenario
#
# Use GridPath to solve a specific scenario `scenario_name` in the file `<scenarios.csv>`. The headers on the `<scenarios.csv>` file are the names of the scenarios. Solve a scenario (`--scenario`) `scenario_name` imported to a database (`--database`) and save it to a directory (`--scenario_location`) `path_to_scenarios` with the following commands:

# %% [markdown]
# * Solve scenario: `VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24`

# %%
# %run -i /Users/Guille/Desktop/state-level_model/gridpath/gridpath/run_end_to_end.py \
        --database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db \
        --scenario VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24 \
        --scenario_location /Users/Guille/Desktop/state-level_model/scenarios
# Out:
# Running scenario VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24 end to end
# Process ID is 24645
# End-to-end run started on 2024-09-10 16:19:17.531269
# Getting inputs... (connected to database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db)
#
# Running optimization for scenario VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# Building model...
# Loading data...
# Creating problem instance...
# Solving...
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Sep  3 2024
#
# command line - /Users/Guille/opt/anaconda3/envs/wri-india/bin/cbc -Threads 4.0 -printingOptions all -import /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmp7emhbe8k.pyomo.lp -stat=1 -solve -solu /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmp7emhbe8k.pyomo.soln (default strategy 1)
# String of 4.0 is illegal for integer parameter threads value remains 0
# Option for printingOptions changed from normal to all
# ...

# %% [markdown]
# * Solve scenario: `VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24`

# %%
# %run -i /Users/Guille/Desktop/state-level_model/gridpath/gridpath/run_end_to_end.py \
        --database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db \
        --scenario VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24 \
        --scenario_location /Users/Guille/Desktop/state-level_model/scenarios
# Out:
# Running scenario VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24 end to end
# Process ID is 24645
# End-to-end run started on 2024-09-10 16:23:01.956820
# Getting inputs... (connected to database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db)
#
# Running optimization for scenario VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# Building model...
# Loading data...
# Creating problem instance...
# Solving...
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Sep  3 2024
#
# command line - /Users/Guille/opt/anaconda3/envs/wri-india/bin/cbc -Threads 4.0 -printingOptions all -import /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmpw3ooj_du.pyomo.lp -stat=1 -solve -solu /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmpw3ooj_du.pyomo.soln (default strategy 1)
# String of 4.0 is illegal for integer parameter threads value remains 0
# Option for printingOptions changed from normal to all
# ...

# %% [markdown]
# * Solve scenario: `VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24`

# %%
# %run -i /Users/Guille/Desktop/state-level_model/gridpath/gridpath/run_end_to_end.py \
        --database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db \
        --scenario VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24 \
        --scenario_location /Users/Guille/Desktop/state-level_model/scenarios
# Out:
# Running scenario VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24 end to end
# Process ID is 24645
# End-to-end run started on 2024-09-10 16:26:46.029224
# Getting inputs... (connected to database /Users/Guille/Desktop/state-level_model/db/TN_7-2050-24.db)
#
# Running optimization for scenario VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# Building model...
# Loading data...
# Creating problem instance...
# Solving...
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Sep  3 2024
#
# command line - /Users/Guille/opt/anaconda3/envs/wri-india/bin/cbc -Threads 4.0 -printingOptions all -import /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmpvsv_fin7.pyomo.lp -stat=1 -solve -solu /var/folders/0c/ffx2kgyn7xq4krqrpsv67l3m0000gn/T/tmpvsv_fin7.pyomo.soln (default strategy 1)
# String of 4.0 is illegal for integer parameter threads value remains 0
# Option for printingOptions changed from normal to all
# ...

# %% [markdown]
# # Vizualization

# %% [markdown]
# Define root directory to the project files (`root`), path to vizualization functionalities (`path_to_software`), define the system paths to the scenarios (`path_to_scenarios`), and where to save the graphs (`path_to_images`).

# %%
from loading_utils import * 
from plotting_utils import * 

import pandas as pd

root = r'/Users/Guille/Desktop/state-level_model/'

path_to_software  = root + r'software/'
path_to_scenarios = root + r'scenarios/'
path_to_images    = root + r'images/'

# %% [markdown]
# Load zones, scenarios, labels `<scenario_labels.csv>` and technology colors `<technology_labels.csv>` for plotting new and exisitng capacity graph

# %%
scen_labels_ = pd.read_csv(root + 'software/scenario_labels.csv') 
tech_labels_ = pd.read_csv(root + 'software/technology_labels.csv')

# %% [markdown]
# * Load new and existing capacity for different scenarios and group capacity by technologies

# %%
capacity_         = _load_new_and_existing_capacity(scen_labels_, path_to_scenarios)
grouped_capacity_ = _group_capacity_technologies(capacity_, tech_labels_)
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24

# %% [markdown]
# * Plot new and existing capacity for different scenarios

# %%
_plot_new_and_existing_capacity(grouped_capacity_, scen_labels_, tech_labels_,
                                title        = 'Tamil Nadu',
                                units_label  = 'Existing & New Capacity (GW)',
                                units        = 1e3,
                                legend       = True,
                                save         = True,
                                file_name    = root + r'images/group_installed_capacity.png',
                                y_period     = -28,
                                y_grid_inc   = 25,
                                div_line_len = -0.275,)

# %% [markdown]
# * Load energy dispatch for different scenarios and group energy dispatch by technologies

# %%
dispatch_        = _load_dispatch(scen_labels_, path_to_scenarios)
grouped_dispath_ = _group_dispatch_technologies(dispatch_, tech_labels_)
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24

# %% [markdown]
# * Plot energy dispatch per technology for different scenarios

# %%
_plot_dispatch(grouped_dispath_, scen_labels_,  tech_labels_, 
               units        = 1e6, 
               units_label  = r'Electricity Generation (TWh)',
               save         = True,
               legend       = True,
               title        = 'Tamil Nadu',
               file_name    = root + r'group_electricity_generation.png',
               y_period     = -69, 
               y_grid_inc   = 25,
               div_line_len = -.28)

# %% [markdown]
# * Load GHG emissions and load demand date for different scenarios

# %%
emissions_, demands_ = _load_GHG_emissions(scen_labels_, path_to_scenarios)
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24

# %% [markdown]
# * Plot GHG emissions for different scenarios

# %%
_plot_emissions(emissions_, scen_labels_, 
                save       = True,
                legend     = True,
                units      = 1e6,
                unit_label = r'GHG Emissions (MtCO$_2$)',
                title      = 'Tamil Nadu',
                file_name  = root + r'images/GHG_emissions.png')

# %% [markdown]
# * Processing GHG emissions intensity for different scenarios

# %%
emissions_, demands_ = _GHG_emissions_intensity(emissions_, demands_)
# Out:
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24

# %% [markdown]
# * Plot GHG emissions intensity for different scenarios

# %%
_plot_emissions_intensity(emissions_, scen_labels_, 
                          save       = True,
                          legend     = True,
                          unit_label = r'GHG Intensity (MtCO$_2$/MWh)',
                          title      = 'Tamil Nadu',
                          file_name  = root + r'images/GHG_emissions_intensity.png')

# %% [markdown]
# * Load system cost data for different scenarios

# %%
system_cost_ = _load_system_cost(scen_labels_, path_to_scenarios)
# Out:
# VRElow_STlow_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREmid_STmid_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24
# VREhigh_SThigh_CONVmid_BPHS_NuclearPVboth_45Ret_PRM110_TN_3_2030_24

# %% [markdown]
# * Plot LCOE system cost for different scenarios

# %%
_plot_system_cost(system_cost_, scen_labels_, 
                  save       = True, 
                  legend     = True,
                  unit_label = r'Costs (USD per MWh)', 
                  title      = 'Tamil Nadu', 
                  file_name  = root + r'images/system_cost.png')
